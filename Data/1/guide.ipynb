# %% [markdown]
# ## Неоднозначное соотнесение таблицы и графа
# Данный типаж задач у нас основан на таблице и картинке, где нам надо найти либо длину пути из одного населённого пункта в другой, либо подписать населённого пункта соответствующими номерами
#
# Для решения данных задач нам чаще всего даны два случая (картинка дана всегда):
# 1. таблица лишь с отмеченными ячейками
# 2. таблица, где в ячейках указана длина пути
#
# Разберём решения на примере:
# 1. Task - 26975
#
# ![](https://github.com/vaskers5/Ege_Solve_Base/blob/main/Data/1/data/ambiguous%20correlation/26975.png)
#
# > Первым делом следует искать такие населённые пункты, у которых число дорог смежных им отличается от любого другого населённого пункта. В нашем примере это населённый пункт К и Ж, из которого есть лишь 2 дороги, а во всех остальных населённых пунктах - 3. Смотрим по таблице, где отмечены две дороги - это у нас строки 2 и 7 (можно смотреть и по столбцам, кому как удобнее). Замечаем, что эти два населённых пункта соединены с одним и тем же населённым пунктом, а именно Д - ищем в таблице в строчках 2 и 7 общий столбец, где была бы отмеченная ячейка. Видим столбец 3, значит это населённый пункт Д. Теперь рассматриваем строчку 3, так как мы уже знаем, что 2 и 7 - населённый пункт К и Ж, то ячейка 4 - населённый пункт В. Надо искать ещё населённый пункты, которые мы точно сможем определить - это смежные К и Ж, так как мы уже выяснили, куда у них ведёт одна из дорог. Также смотрим на картинку и таблицу - строка 2 соединена с населённым пунктом 6 - это Е. Аналогично с 7 строкой и 5 населённым пунктом - А. Теперь мы знаем, что населённый пункт В(4) соединён с Е(6) и Д(3), а значит населённый пункт Г - 8. Так как Г(8) соединён с В(4) и А(5), то населённый пункт Б - 1.
#
# Ответ: 14
#
# 2. Task - 29110
#
# ![](https://github.com/vaskers5/Ege_Solve_Base/blob/main/Data/1/data/ambiguous%20correlation/29110.png)
#
# > Ситуация похожа на прошлый типаж таких задач, нам снова следует искать такие населённый пункты, у которых число дорог смежных им отличается от любого другого населённого пункта. Населённый пункт Д имеет больше всего смежных дорог - 4, смотрим в таблицу - строка 4 имеет 4 дороги. Смотрим на смежные населённые пункты для Д - Б и Ж смежны, Ж и Е тоже, значит, если в таблице среди столбцов 1, 2, 5, 6 (дороги из Д до его смежных населённых пунктов) найдутся такие, которые смежны и между собой, то это будут населённые пункты Б, Ж, Е. В свою очередь Г не соединён ни с одним из этих городов. Анализируя таблицу понимаем, что 1 строка - Б или Е, 2 строка - Б или Е, 5 строка - Ж (2 смежных города, которые смежны Д, то есть Б и Е), значит 6 строка - Г. Г имеет 3 пути, связанных с Д, А и В, нам по условию сказали, что путь АГ < ВГ, значит, отметая путь ДГ, ищем минимальный из оставшихся двух, который и будет являться путём АГ. Населённый пункт А - 7 строка таблицы, тогда В - 3. Теперь, когда мы знаем, что В(3), Д(4), Ж(5) - все населённые пункты смежные с Е, то нам остаётся лишь найти строку в таблице, ячейки которой будут отмечены в столбцах 3, 4, 5 - строка 1. Дорога ЕЖ(15) = 24
#
# Ответ: 24

# %% [markdown]
# ## Однозначное соотнесение таблицы и графа

# %% [markdown]
# ## Поиск оптимального маршрута по таблице
