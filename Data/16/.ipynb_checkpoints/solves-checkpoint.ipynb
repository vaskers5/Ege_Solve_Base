# %% [markdown]
# ### Task_4189_def

# %%
def f(n):
    if n == 0:
        return 2
    elif 0 < n <= 15:
        return f(n - 1)
    elif 15 < n < 95:
        return 1.6 * f(n - 3)
    elif n >= 95:
        return 3.3 * f(n - 2)


x = str(int(f(33)))
nums = {}
for elem in x:
    if elem in nums:
        nums[elem] += 1
    else:
        nums.update({elem: 1})
        
print(max(nums))
# Out:
# 3

# %% [markdown]
# ### Task_3986_def

# %%
def f(n):
    if n == 0:
        return 0
    
    elif n % 2 == 0 and n > 0:
        return f(n//2) + 3
    
    elif n % 2 != 0 and n > 0:
        return 2 * f(n - 1) + 1

print(len(set(map(f, range(1, 1001)))))
# Out:
# 348

# %% [markdown]
# ### Task_3819_def

# %%
def f(n):
    if n < 2:
        return 1
    elif n >= 2 and n % 3 == 0:
        return f(n // 3) + 1
    elif n >= 2 and n % 3 != 0:
        return f(n - 2) + 5

ans = 0
for n in range(100000):
    if f(n) == 73:
        print(n)
        break
# Out:
# 5101

# %% [markdown]
# ### Task_3142_def

# %%
def f(n, m):
    if n < m:
        n, m = m, n
    if n != m:
        return f(n - m, m)
    else:
        return n

for n in range(1, 1000):
    for m in range(1, 1000):
        if f(n, m) > 15 and n != m:
            print(n, m)
# Out:
# 16 32
# 16 48
# 16 64
# 16 80
# 16 96
# 16 112
# 16 128
# 16 144
# 16 160
# 16 176
# 16 192
# 16 208
# 16 224
# 16 240
# 16 256
# 16 272
# 16 288
# 16 304
# 16 320
# 16 336
# 16 352
# 16 368
# 16 384
# 16 400
# 16 416
# 16 432
# 16 448
# 16 464
# 16 480
# 16 496
# 16 512
# 16 528
# 16 544
# 16 560
# 16 576
# 16 592
# 16 608
# 16 624
# 16 640
# 16 656
# 16 672
# 16 688
# 16 704
# 16 720
# 16 736
# 16 752
# 16 768
# 16 784
# 16 800
# 16 816
# 16 832
# 16 848
# 16 864
# 16 880
# 16 896
# 16 912
# 16 928
# 16 944
# 16 960
# 16 976
# 16 992
# 17 34
# 17 51
# 17 68
# 17 85
# 17 102
# 17 119
# 17 136
# 17 153
# 17 170
# 17 187
# 17 204
# 17 221
# 17 238
# 17 255
# 17 272
# 17 289
# 17 306
# 17 323
# 17 340
# 17 357
# 17 374
# 17 391
# 17 408
# 17 425
# 17 442
# 17 459
# 17 476
# 17 493
# 17 510
# 17 527
# 17 544
# 17 561
# 17 578
# 17 595
# 17 612
# 17 629
# 17 646
# 17 663
# 17 680
# 17 697
# 17 714
# 17 731
# 17 748
# 17 765
# 17 782
# 17 799
# 17 816
# 17 833
# 17 850
# 17 867
# 17 884
# ...
